# %% [markdown]
# <a href="https://colab.research.google.com/github/yashshinde0607/DS_LAB_SE_B_67/blob/main/TEST1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
b = 5

# Addition
sum_result = a + b
print(f"Addition: {a} + {b} = {sum_result}")

# Subtraction
difference_result = a - b
print(f"Subtraction: {a} - {b} = {difference_result}")

# Multiplication
product_result = a * b
print(f"Multiplication: {a} * {b} = {product_result}")

# Division
division_result = a / b
print(f"Division: {a} / {b} = {division_result}")

# Floor Division (integer division)
floor_division_result = a // b
print(f"Floor Division: {a} // {b} = {floor_division_result}")

# Modulus (remainder)
modulus_result = a % b
print(f"Modulus: {a} % {b} = {modulus_result}")

# Exponentiation
exponentiation_result = a ** b
print(f"Exponentiation: {a} ** {b} = {exponentiation_result}")
# Out:
# Addition: 10 + 5 = 15
# Subtraction: 10 - 5 = 5
# Multiplication: 10 * 5 = 50
# Division: 10 / 5 = 2.0
# Floor Division: 10 // 5 = 2
# Modulus: 10 % 5 = 0
# Exponentiation: 10 ** 5 = 100000
